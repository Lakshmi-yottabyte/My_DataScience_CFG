# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("thanks MrA")
# Out:
# thanks MrA

# %%
name="Alice"
print(name[0])
# Out:
# A

# %%
name="Lakshmi1980"
print(name[-4:])
# Out:
# 1980

# %%
fruits=["apple", "banana", "cherry"]
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.pop()
# Out:
# 'cherry'

# %%
print(fruits)
# Out:
# ['apple', 'banana']

# %%
fruits.append("grapes")
print(fruits)
# Out:
# ['apple', 'banana', 'grapes', 'grapes']
